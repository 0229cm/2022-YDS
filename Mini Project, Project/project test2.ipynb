# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r'C:\Users\min\Desktop\파이널프로젝트_RAW_210329_210926.xlsx')

# %%
df.head()
# Out:
#        id  customer_id  course_id     type      state  \
# 0  970634     504760.0   201435.0    ORDER  CANCELLED
# 1  970650     432862.0   203178.0    ORDER  CANCELLED
# 2  970657      72297.0   204246.0  PAYMENT  COMPLETED
# 3  970656      72297.0   204246.0    ORDER  CANCELLED
# 4  970658     478028.0   201797.0  PAYMENT  COMPLETED
#
#                     course_title category_title  format        completed_at  \
# 0      올인원 패키지 : 알고리즘 기술면접 완전 정복          프로그래밍     올인원 2021-03-28 15:00:11
# 1    초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원 2021-03-28 15:16:53
# 2           시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인 2021-03-28 15:21:43
# 3           시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인 2021-03-28 15:21:43
# 4  올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원 2021-03-28 15:21:54
#
#    transaction_amount              coupon_title  coupon_discount_amount  \
# 0               90500                       NaN                     NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105419 entries, 0 to 105418
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      105419 non-null  int64
#  1   customer_id             105416 non-null  float64
#  2   course_id               100212 non-null  float64
#  3   type                    105419 non-null  object
#  4   state                   105419 non-null  object
#  5   course_title            105403 non-null  object
#  6   category_title          105395 non-null  object
#  7   format                  105403 non-null  object
#  8   completed_at            105419 non-null  datetime64[ns]
#  9   transaction_amount      105419 non-null  int64
#  10  coupon_title            31817 non-null   object
#  11  coupon_discount_amount  31817 non-null   float64
#  12  sale_price              104291 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# id                            0
# customer_id                   3
# course_id                  5207
# type                          0
# state                         0
# course_title                 16
# category_title               24
# format                       16
# completed_at                  0
# transaction_amount            0
# coupon_title              73602
# coupon_discount_amount    73602
# sale_price                 1128
# tax_free_amount            1128
# pg                        15075
# method                    13096
# subcategory_title         19829
# marketing_start_at        17979
# dtype: int64

# %% [markdown]
# # Customer_id 결측치 3개는 제외시켜야 할 것 같음.
#  ##

# %%
df_sample_1 = df[['type']]
df_sample_1
# Out:
#            type
# 0         ORDER
# 1         ORDER
# 2       PAYMENT
# 3         ORDER
# 4       PAYMENT
# ...         ...
# 105414  PAYMENT
# 105415  PAYMENT
# 105416  PAYMENT
# 105417  PAYMENT
# 105418  PAYMENT
#
# [105419 rows x 1 columns]

# %%
df[df['type'] == 'ORDER']
# Out:
#             id  customer_id  course_id   type      state  \
# 0       970634     504760.0   201435.0  ORDER  CANCELLED
# 1       970650     432862.0   203178.0  ORDER  CANCELLED
# 3       970656      72297.0   204246.0  ORDER  CANCELLED
# 5       970655     478028.0   201797.0  ORDER  CANCELLED
# 6       970614     477910.0        NaN  ORDER  CANCELLED
# ...        ...          ...        ...    ...        ...
# 77380  1232099     392104.0   205949.0  ORDER  COMPLETED
# 77383  1232107     136955.0   202785.0  ORDER  COMPLETED
# 77385  1232110     136955.0   202284.0  ORDER  COMPLETED
# 77386  1232108     390199.0   201582.0  ORDER  COMPLETED
# 77387  1232113     438778.0   205625.0  ORDER  COMPLETED
#
#                                           course_title category_title  format  \
# 0                            올인원 패키지 : 알고리즘 기술면접 완전 정복          프로그래밍     올인원
# 1                          초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원
# ...

# %%
df[df['type'] == 'PAYMENT']
# Out:
#              id  customer_id  course_id     type      state  \
# 2        970657      72297.0   204246.0  PAYMENT  COMPLETED
# 4        970658     478028.0   201797.0  PAYMENT  COMPLETED
# 8        970669     478033.0   203178.0  PAYMENT  COMPLETED
# 10       970671     469860.0   203644.0  PAYMENT  COMPLETED
# 14       970676     478035.0   203720.0  PAYMENT  COMPLETED
# ...         ...          ...        ...      ...        ...
# 105414  1364995     640697.0   205365.0  PAYMENT  CANCELLED
# 105415  1364998     670896.0   204159.0  PAYMENT  CANCELLED
# 105416  1364996     640697.0   205365.0  PAYMENT  COMPLETED
# 105417  1365005     670896.0   204159.0  PAYMENT  CANCELLED
# 105418  1365007     610626.0   206720.0  PAYMENT  COMPLETED
#
#                                           course_title category_title  format  \
# 2                                 시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인
# 4                        올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원
# ...

# %%
df_sample_1[df_sample_1 == 'ORDER'].count()
# Out:
# type    40159
# dtype: int64

# %%
df_sample_1[df_sample_1 == 'PAYMENT'].count()
# Out:
# type    61433
# dtype: int64

# %%
df_sample_1[df_sample_1 == 'REFUND'].count()
# Out:
# type    3824
# dtype: int64

# %%
df_sample_1[df_sample_1 == 'TRANSACTION'].count()
# Out:
# type    3
# dtype: int64

# %%
df_sample_1.isnull().sum()
# Out:
# type    0
# dtype: int64

# %%
df.duplicated
# Out:
# <bound method DataFrame.duplicated of              id  customer_id  course_id     type      state  \
# 0        970634     504760.0   201435.0    ORDER  CANCELLED
# 1        970650     432862.0   203178.0    ORDER  CANCELLED
# 2        970657      72297.0   204246.0  PAYMENT  COMPLETED
# 3        970656      72297.0   204246.0    ORDER  CANCELLED
# 4        970658     478028.0   201797.0  PAYMENT  COMPLETED
# ...         ...          ...        ...      ...        ...
# 105414  1364995     640697.0   205365.0  PAYMENT  CANCELLED
# 105415  1364998     670896.0   204159.0  PAYMENT  CANCELLED
# 105416  1364996     640697.0   205365.0  PAYMENT  COMPLETED
# 105417  1365005     670896.0   204159.0  PAYMENT  CANCELLED
# 105418  1365007     610626.0   206720.0  PAYMENT  COMPLETED
#
#                            course_title category_title  format  \
# 0             올인원 패키지 : 알고리즘 기술면접 완전 정복          프로그래밍     올인원
# 1           초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원
# ...

# %%
df_sample_2 = df[['state']]
df_sample_2
# Out:
#             state
# 0       CANCELLED
# 1       CANCELLED
# 2       COMPLETED
# 3       CANCELLED
# 4       COMPLETED
# ...           ...
# 105414  CANCELLED
# 105415  CANCELLED
# 105416  COMPLETED
# 105417  CANCELLED
# 105418  COMPLETED
#
# [105419 rows x 1 columns]

# %%
df_sample_2[df_sample_2 == 'CANCELLED'].count()
# Out:
# state    41279
# dtype: int64

# %%
df_sample_2[df_sample_2 == 'COMPLETED'].count()
# Out:
# state    62763
# dtype: int64

# %%
df_sample_2[df_sample_2 == 'PENDING'].count()
# Out:
# state    1144
# dtype: int64

# %%
df_sample_2[df_sample_2 == 'TRANSCATION'].count()
# Out:
# state    0
# dtype: int64

# %%
df_sample_3 = df[['state']]
df_sample_3
# Out:
#             state
# 0       CANCELLED
# 1       CANCELLED
# 2       COMPLETED
# 3       CANCELLED
# 4       COMPLETED
# ...           ...
# 105414  CANCELLED
# 105415  CANCELLED
# 105416  COMPLETED
# 105417  CANCELLED
# 105418  COMPLETED
#
# [105419 rows x 1 columns]

# %%
df_sample_3.drop_duplicates(['state'])
# Out:
#            state
# 0      CANCELLED
# 2      COMPLETED
# 50       PENDING
# 242      DELETED
# 13438  REQUESTED

# %%
df_sample_4 = df[['course_title']]
df_sample_4
# Out:
#                            course_title
# 0             올인원 패키지 : 알고리즘 기술면접 완전 정복
# 1           초격차 패키지 : 한번에 끝내는 영상 촬영과 편집
# 2                  시크릿코드 : 프론트엔드 실무 완성편
# 3                  시크릿코드 : 프론트엔드 실무 완성편
# 4         올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX
# ...                                 ...
# 105414  초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기
# 105415              부동산 디벨로퍼 아카데미 : 인허가
# 105416  초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기
# 105417              부동산 디벨로퍼 아카데미 : 인허가
# 105418               용호수의 돈 버는 실전 영상 제작
#
# [105419 rows x 1 columns]

# %%
df_sample_4.drop_duplicates(['course_title'])
# Out:
#                                            course_title
# 0                             올인원 패키지 : 알고리즘 기술면접 완전 정복
# 1                           초격차 패키지 : 한번에 끝내는 영상 촬영과 편집
# 2                                  시크릿코드 : 프론트엔드 실무 완성편
# 4                         올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX
# 6       프로모션 : 2021 내 커리어 지켜 줄 UX/UI 디자인 한끝세트 (3월 프리패스)
# ...                                                 ...
# 104905             (B2B) (주)공정씨컴퍼니 온라인 구독 올 플랜 - 비대면바우처
# 105119                 올인원 패키지 : Unity를 활용한 영화 애니메이션 제작
# 105163                 (B2B) 그린오션스 온라인 구독 올 플랜 - 비대면바우처
# 105174                  (B2B) 디캠프 패밀리사 온라인 구독 올 플랜 (9월)
# 105265                 (B2B) (주)오디 온라인 구독 올 플랜 - 비대면바우처
#
# [1642 rows x 1 columns]
